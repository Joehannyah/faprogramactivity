# %% [markdown]
# <a href="https://colab.research.google.com/github/Joehannyah/faprogramactivity/blob/main/fa5program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print (input("What is the product you would like to purchase?"))
num1 = int(input("How many products would you like?"))
num2 = int(input("How much does the product cost(in pesos)?"))

#function
def totalprice(num1, num2):
  return num1 * num2

#output
print("Your total price is", totalprice(num1, num2))
# Out:
# What is the product you would like to purchase?fish
# fish
# How many would you like?6
# How much does the product cost?7
# Your total price is 42
